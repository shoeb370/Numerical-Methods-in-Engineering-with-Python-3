# %% [markdown]
# # Relational Operators

# %%
#comparision operator

# %%
a = 10
b = 20
c = 10

# %%
#less than

# %%
a<b
# Out:
# True

# %%
#greater than

# %%
b>a
# Out:
# True

# %%
a>b
# Out:
# False

# %%
#greater than equal to
#>=
b>=a
# Out:
# True

# %%
a>=c
# Out:
# True

# %%
a == c
# Out:
# True

# %%
a!= c
# Out:
# False

# %%
a!=b #10 and 20
# Out:
# True

# %%
a<= b
# Out:
# True

# %%
a<= c
# Out:
# True
